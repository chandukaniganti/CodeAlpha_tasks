# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df = pd.read_csv(r"C:\Users\chandu kaniganti\OneDrive\Documents\Desktop\code alpha\data_analysis_books.csv")
df.head()
# Out:
#                     Title                 Category  Price  Rating  Reviews
# 0           Python Basics              Programming    450     4.2      120
# 1   Data Science Handbook             Data Science    650     4.5      200
# 2  Machine Learning Guide         Machine Learning    800     4.7      180
# 3         AI Fundamentals  Artificial Intelligence    720     4.4      150
# 4    Statistics Made Easy               Statistics    500     4.0       90

# %%
# Example questions:
# 1. What is the average price of books?
# 2. Which rating appears most frequently?
# 3. Are higher-rated books more expensive?

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Title     10 non-null     object
#  1   Category  10 non-null     object
#  2   Price     10 non-null     int64
#  3   Rating    10 non-null     float64
#  4   Reviews   10 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 532.0+ bytes
#             Price     Rating     Reviews
# count   10.000000  10.000000   10.000000
# mean   615.000000   4.320000  138.000000
# std    186.204786   0.265832   43.153473
# min    350.000000   3.900000   60.000000
# 25%    462.500000   4.125000  112.500000
# 50%    625.000000   4.350000  145.000000
# 75%    765.000000   4.500000  167.500000
# max    900.000000   4.700000  200.000000

# %%
# Force the column to string, remove the symbol, then convert to float
df['Price'] = df['Price'].astype(str).str.replace('£', '').astype(float)
df.isnull().sum()
# Out:
# Title       0
# Category    0
# Price       0
# Rating      0
# Reviews     0
# dtype: int64

# %%
sns.countplot(x='Rating', data=df)
plt.title("Distribution of Book Ratings")
plt.show()

# %%
sns.boxplot(x='Rating', y='Price', data=df)
plt.title("Price vs Rating")
plt.show()

# %%
sns.boxplot(y=df['Price'])
plt.title("Outlier Detection in Book Prices")
plt.show()

# %%
high_rating = df[df['Rating'].isin(['Four', 'Five'])]['Price']
low_rating = df[df['Rating'].isin(['One', 'Two'])]['Price']

high_rating.mean(), low_rating.mean()
# Out:
# (nan, nan)
